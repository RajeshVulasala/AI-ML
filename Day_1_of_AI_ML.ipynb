# %% [markdown]
# <a href="https://colab.research.google.com/github/RajeshVulasala/AI-ML/blob/main/Day_1_of_AI_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Learn Python
# 1. Printing
# 3. Arithmetic
# 4. Comments
# 5. Variables (Creating, Manipulating, Using Mutliple Variables, Debuggung)

# %%
print("Hello Rajesh Vulasala")
# Out:
# Hello Rajesh Vulasala

# %%
# Arithmetic +,-,*,/,**
print(1+2)
print(1-2)
print(4/2)
print(4%2)
print(4*2)
print(4**2)

# You can control the order of calculation with brackets
print(((1 + 3) * (9 - 2) / 2) ** 2)
# Out:
# 3
# -1
# 2.0
# 0
# 8
# 16
# 196.0

# %%
# Comments
