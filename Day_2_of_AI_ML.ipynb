# %% [markdown]
# <a href="https://colab.research.google.com/github/RajeshVulasala/AI-ML/blob/main/Day_2_of_AI_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to calculate mins per day
# 24hrs 1hr=60mints

# %% [markdown]
# to get the fraction tota N/Total.

# %%
print(342/891)
# Out:
# 0.3838383838383838

# %% [markdown]
# FUNCTIONS : A block of code which can be reusable.

# %%
def add_3(input):      # def = used to define a funcyion in python
  output = input + 3   # if the return written in the end of the function then function ended here.
  return output

# %% [markdown]
# How to run a function

# %%
output = add_3(10)
print(output)
# Out:
# 13

# %% [markdown]
# A tough example 1.your helping a friend to calculate weekly paycheck after taxes. a. 12% of salaray is taken for taxes and they only take home 88% and they are paid hourly, at a rate of $15/hour.

# %%
def paycheck (No_hrs):
  totalerned = No_hrs * 15
  savings = totalerned * .88
  return savings

totalsaved = paycheck(40)
print(totalsaved)
# Out:
# 528.0

# %% [markdown]
# Variable "scope" : Variables defined inside the function body cannot be accessed outside of the function.

# %%
# Example:
print(savings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_167/471323972.py in <cell line: 0>()
#       1 # Example:
# ----> 2 print(savings)
#
# NameError: name 'savings' is not defined

# %% [markdown]
# Functions with multiple arguments

# %%
#  same above example
def paycheck_with_multivariables (Nhrs, slryhr, taxamt):
  earned = Nhrs * slryhr
  saving = earned * taxamt
  return earned
totalsavings = paycheck_with_multivariables(40, 15, .88)
print(totalsavings)
# Out:
# 600

# %% [markdown]
# Functions has diff types:
# 1. Fun with no arg and no return value.
# 2. Fun with arg and without return value
# 3. Fun with arg and with return value
# 4. Fun without arg and with return value.

# %%
# Fun with no arg and no return value
def print_ex ():
  print("Rajesh Vulasala")
  # call function
print_ex()
# Out:
# Rajesh Vulasala
